# %% [markdown]
# ### Visual Wake Words Dataset Builder
#
# ##### Run as a Jupyter notebook on the GCP AI platform : TF 1.0 : CPU-only

# %% [markdown]
# #### Clone Tensorflow repo

# %%
! cd ~
! git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 34583 (delta 5), reused 8 (delta 0), pack-reused 34564
# Receiving objects: 100% (34583/34583), 512.67 MiB | 45.99 MiB/s, done.
# Resolving deltas: 100% (22292/22292), done.

# %% [markdown]
# #### Setup the environment

# %%
! pip install contextlib2
import os
new_python_path = (os.environ.get("PYTHONPATH") or '') + ":models/research/slim"
# %env PYTHONPATH=$new_python_path
# Out:
# ...
# env: PYTHONPATH=:models/research/slim

# %% [markdown]
# #### Download and build model training set (this takes a while)
#
# ##### Below uses the default 0.0005 area threshold and 'person' as the foreground class

# %%
! python models/research/slim/download_and_convert_data.py \
    --dataset_name=visualwakewords \
    --dataset_dir=./visualwakewords

# %% [markdown]
# ##### ...or this alternative to customise these parameters

# %%
! python models/research/slim/download_and_convert_data.py \
    --logtostderr \
    --dataset_name=visualwakewords \
    --dataset_dir=./visualwakewords \
    --small_object_area_threshold=0.005 \
    --foreground_class_of_interest='dog'
# Out:
# WARNING:tensorflow:From /home/jupyter/models/research/slim/datasets/download_and_convert_visualwakewords.py:107: The name tf.gfile.IsDirectory is deprecated. Please use tf.io.gfile.isdir instead.
#
# W0426 16:28:28.848322 139853126186368 module_wrapper.py:139] From /home/jupyter/models/research/slim/datasets/download_and_convert_visualwakewords.py:107: The name tf.gfile.IsDirectory is deprecated. Please use tf.io.gfile.isdir instead.
#
# WARNING:tensorflow:From /home/jupyter/models/research/slim/datasets/dataset_utils.py:151: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W0426 16:28:28.848685 139853126186368 module_wrapper.py:139] From /home/jupyter/models/research/slim/datasets/dataset_utils.py:151: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# File train2014.zip has been already downloaded at ./visualwakewords/coco_dataset/train2014.zip. Unzipping it....
# ...
